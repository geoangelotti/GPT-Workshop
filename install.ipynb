# %% [markdown]
# ## Installation
# Please have the correct Kernel selected

# %%
# We always start with a dataset to train on. Let's download the tiny shakespeare dataset
# !pdm install -q
# Out:
# ⠋ Resolving packages from lockfile...
# Synchronizing working set with resolved packages: 2 to add, 0 to update, 0 to
# remove
#
#
# 0:00:00 Synchronizing 0/?
#   ⠋ Installing pyarrow 20.0.0...
#   ⠋ Installing torch 2.5.1...
#
#   ⠸ Installing pyarrow 20.0.0...
#   ⠸ Installing torch 2.5.1...
#
#   ⠦ Installing pyarrow 20.0.0...
#   ⠦ Installing torch 2.5.1...
#
#   ⠏ Installing pyarrow 20.0.0...
#   ⠏ Installing torch 2.5.1...
#
#   ⠹ Installing pyarrow 20.0.0...
#   ⠹ Installing torch 2.5.1...
#
#   ⠦ Installing pyarrow 20.0.0...
#   ⠦ Installing torch 2.5.1...
#
#   ⠏ Installing pyarrow 20.0.0...
#   ⠏ Installing torch 2.5.1...
#
#   ⠹ Installing pyarrow 20.0.0...
#   ⠹ Installing torch 2.5.1...
#
#   ⠴ Installing pyarrow 20.0.0...
#   ⠴ Installing torch 2.5.1...
#
#   ⠇ Installing pyarrow 20.0.0...
#   ⠇ Installing torch 2.5.1...
#
#   ⠹ Installing pyarrow 20.0.0...
#   ⠹ Installing torch 2.5.1...
#
#   ⠴ Installing pyarrow 20.0.0...
#   ⠴ Installing torch 2.5.1...
#
# ...
